# %% [markdown]
# ## **Fundamentals of Machine Learning: Final project**

# %% [markdown]
# This dataset contains simulated mushrooms for binary classification into edible and poisonous and it is available at the following link:
#
# https://archive.ics.uci.edu/dataset/848/secondary+mushroom+dataset

# %% [markdown]
# ## Dataset import and Data cleaning

# %% [markdown]
# Import libraries:

# %%
import pandas as pd
import numpy as np
import re

# %%
# Load CSV file into DataFrame
pd.set_option('display.max_columns', None)
mushrooms_train_df = pd.read_csv('primary_data.csv', delimiter=';')

# %%
mushrooms_train_df.head(20)
# Out:
#                family                    name class cap-diameter  cap-shape  \
# 0      Amanita Family              Fly Agaric     p     [10, 20]     [x, f]
# 1      Amanita Family             Panther Cap     p      [5, 10]     [p, x]
# 2      Amanita Family       False Panther Cap     p     [10, 15]     [x, f]
# 3      Amanita Family             The Blusher     e      [5, 15]     [x, f]
# 4      Amanita Family               Death Cap     p      [5, 12]     [x, f]
# 5      Amanita Family         False Death Cap     e       [4, 9]        [x]
# 6      Amanita Family        Destroying Angel     p      [5, 10]        [b]
# 7      Amanita Family          Tawny Grisette     e       [4, 8]     [c, x]
# 8      Lepiota Family        Parasol Mushroom     e     [10, 25]     [p, f]
# 9      Lepiota Family          Shaggy Parasol     e     [12, 18]        [x]
# 10     Lepiota Family        Stinking Parasol     p       [2, 5]     [b, f]
# 11  Tricholoma Family         Saffron Parasol     p       [2, 5]        [x]
# 12  Tricholoma Family            The Deceiver     e       [1, 4]     [f, s]
# 13  Tricholoma Family       Amethyst Deceiver     e       [1, 4]        [x]
# 14  Tricholoma Family             Wood Blewit     e      [5, 15]     [f, s]
# 15  Tricholoma Family            Field Blewit     e      [5, 12]  [x, f, s]
# 16  Tricholoma Family          Clouded Agaric     e      [8, 20]  [x, f, s]
# 17  Tricholoma Family  Club-footed Funnel Cap     p       [4, 8]     [x, f]
# 18  Tricholoma Family       Common Funnel Cap     e       [4, 8]        [s]
# 19  Tricholoma Family      Aniseed Funnel Cap     e       [3, 6]        [x]
#
#    Cap-surface     cap-color does-bruise-or-bleed gill-attachment  \
# 0       [g, h]        [e, o]                  [f]             [e]
# 1          [g]           [n]                  [f]             [e]
# 2          NaN        [g, n]                  [f]             [e]
# 3          NaN           [n]                  [t]             NaN
# 4          [h]           [r]                  [f]             NaN
# 5          NaN        [w, y]                  [f]             [e]
# 6          [t]           [w]                  [f]             [e]
# 7       [h, t]           [n]                  [f]             [e]
# 8          [y]        [w, n]                  [f]             NaN
# 9       [e, y]           [n]                  [t]             [e]
# 10         [y]  [e, n, p, w]                  [f]             [e]
# 11         [y]        [y, n]                  [f]             [a]
# 12         [y]           [n]                  [f]          [a, d]
# 13         NaN        [b, u]                  [f]             NaN
# 14         NaN  [l, u, g, n]                  [f]             [s]
# 15         NaN        [g, n]                  [f]             [s]
# 16         [e]        [g, n]                  [f]          [a, d]
# 17         NaN        [g, n]                  [f]             [d]
# 18         NaN           [n]                  [f]             [d]
# 19         NaN     [l, r, w]                  [f]          [a, d]
#
#    gill-spacing gill-color stem-height stem-width stem-root stem-surface  \
# 0           NaN        [w]    [15, 20]   [15, 20]       [s]          [y]
# 1           NaN        [w]     [6, 10]   [10, 20]       NaN          [y]
# 2           NaN        [w]    [10, 12]   [10, 20]       NaN          NaN
# 3           NaN        [w]     [7, 15]   [10, 25]       [b]          NaN
# 4           [c]        [w]    [10, 12]   [10, 20]       NaN          NaN
# 5           NaN        [w]      [5, 7]   [10, 15]       [b]          NaN
# 6           [c]        [w]    [10, 15]   [10, 15]       NaN          [y]
# 7           NaN        [w]    [10, 15]   [10, 15]       NaN          [s]
# 8           NaN        [w]    [15, 35]   [15, 25]       [s]          NaN
# 9           NaN        [w]     [8, 12]   [15, 20]       NaN          NaN
# 10          [c]     [n, w]      [3, 6]     [3, 4]       NaN          [k]
# 11          NaN        [w]      [4, 7]     [3, 4]       NaN          [y]
# 12          [d]        [p]     [3, 10]     [2, 5]       NaN          [i]
# 13          [d]     [u, w]      [4, 8]     [3, 6]       NaN          NaN
# 14          [c]     [b, u]     [5, 10]   [15, 25]       NaN          NaN
# 15          [c]     [g, p]     [4, 10]   [15, 25]       [b]          NaN
# 16          [c]        [w]     [5, 12]   [20, 30]       [s]          NaN
# 17          [c]     [w, y]      [4, 7]       [10]       [b]          NaN
# 18          [c]        [w]      [3, 7]    [6, 10]       NaN          [s]
# 19          NaN        [r]      [4, 8]    [5, 10]       NaN          NaN
#
#    stem-color veil-type veil-color has-ring ring-type Spore-print-color  \
# 0         [w]       [u]        [w]      [t]    [g, p]               NaN
# 1         [w]       [u]        [w]      [t]       [p]               NaN
# 2         [w]       [u]        [w]      [t]    [e, g]               NaN
# 3         [w]       [u]        [w]      [t]       [g]               NaN
# 4         [w]       [u]        [w]      [t]    [g, p]               NaN
# 5      [w, y]       [u]     [y, w]      [t]       [g]               NaN
# 6         [w]       [u]        [w]      [t]    [l, e]               NaN
# 7      [w, n]       [u]        [w]      [f]       [f]               NaN
# 8         [n]       NaN        NaN      [t]       [m]               NaN
# 9         [w]       NaN        NaN      [t]       NaN               NaN
# 10        [w]       NaN        NaN      [t]       [e]               NaN
# 11     [y, n]       NaN        NaN      [t]       [r]               NaN
# 12        [n]       NaN        NaN      [f]       [f]               NaN
# 13        [w]       NaN        NaN      [f]       [f]               NaN
# 14     [b, u]       NaN        NaN      [f]       [f]               NaN
# 15        [u]       NaN        NaN      [f]       [f]               NaN
# 16        [w]       NaN        NaN      [f]       [f]               NaN
# 17        [n]       NaN        NaN      [f]       [f]               NaN
# 18        [w]       NaN        NaN      [f]       [f]               NaN
# 19  [l, r, w]       NaN        NaN      [f]       [f]               NaN
#
#       habitat     season
# 0         [d]  [u, a, w]
# 1         [d]     [u, a]
# 2         [d]     [u, a]
# 3         [d]     [u, a]
# 4         [d]     [u, a]
# 5         [d]     [u, a]
# 6         [d]     [u, a]
# 7         [d]     [u, a]
# 8      [m, d]     [u, a]
# 9      [g, d]     [u, a]
# 10     [m, d]     [u, a]
# 11  [g, h, d]     [u, a]
# 12     [l, h]     [u, a]
# 13        [d]  [u, a, w]
# 14     [l, d]     [a, w]
# 15     [g, d]     [a, w]
# 16     [l, d]     [a, w]
# 17     [l, d]     [a, w]
# 18  [l, d, h]     [u, a]
# 19     [l, d]     [u, a]

# %% [markdown]
# I can already see that there are a lot of NaN values that I'm going to explore later

# %%
# dataset dimensions
mushrooms_train_df.shape
# Out:
# (173, 23)

# %%
# informations about variables
mushrooms_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   family                173 non-null    object
#  1   name                  173 non-null    object
#  2   class                 173 non-null    object
#  3   cap-diameter          173 non-null    object
#  4   cap-shape             173 non-null    object
#  5   Cap-surface           133 non-null    object
#  6   cap-color             173 non-null    object
#  7   does-bruise-or-bleed  173 non-null    object
#  8   gill-attachment       145 non-null    object
#  9   gill-spacing          102 non-null    object
#  10  gill-color            173 non-null    object
#  11  stem-height           173 non-null    object
#  12  stem-width            173 non-null    object
#  13  stem-root             27 non-null     object
#  14  stem-surface          65 non-null     object
#  15  stem-color            173 non-null    object
#  16  veil-type             9 non-null      object
#  17  veil-color            21 non-null     object
#  18  has-ring              173 non-null    object
#  19  ring-type             166 non-null    object
#  20  Spore-print-color     18 non-null     object
#  21  habitat               173 non-null    object
#  22  season                173 non-null    object
# dtypes: object(23)
# memory usage: 31.2+ KB

# %% [markdown]
# I can see that the variables are all categoricals

# %% [markdown]
# the vairiables 'cap-diameter', ' stem.height', 'stem-width' are numeric ranges and I want to convert them to numeric variables by averaging them but keeping the null values unchanged

# %%
def from_interval_to_value(value):
    if pd.isna(value):  # keep Nan
        return np.nan
    if '[' in value and ']' in value:  # check if it's an interval
        numbers = [float(x) for x in value.strip('[]').split(',')]  # Convert numbers
        return sum(numbers) / len(numbers)  # mean
    return value  #return original value if it's not an interval

# %%
columns_with_intervals = ['cap-diameter', 'stem-height', 'stem-width']
for col in columns_with_intervals:
    mushrooms_train_df[col] = mushrooms_train_df[col].apply(from_interval_to_value)

# %%
mushrooms_train_df.head(20).T
# Out:
#                                   0               1                  2   \
# family                Amanita Family  Amanita Family     Amanita Family
# name                      Fly Agaric     Panther Cap  False Panther Cap
# class                              p               p                  p
# cap-diameter                    15.0             7.5               12.5
# cap-shape                     [x, f]          [p, x]             [x, f]
# Cap-surface                   [g, h]             [g]                NaN
# cap-color                     [e, o]             [n]             [g, n]
# does-bruise-or-bleed             [f]             [f]                [f]
# gill-attachment                  [e]             [e]                [e]
# gill-spacing                     NaN             NaN                NaN
# gill-color                       [w]             [w]                [w]
# stem-height                     17.5             8.0               11.0
# stem-width                      17.5            15.0               15.0
# stem-root                        [s]             NaN                NaN
# stem-surface                     [y]             [y]                NaN
# stem-color                       [w]             [w]                [w]
# veil-type                        [u]             [u]                [u]
# veil-color                       [w]             [w]                [w]
# has-ring                         [t]             [t]                [t]
# ring-type                     [g, p]             [p]             [e, g]
# Spore-print-color                NaN             NaN                NaN
# habitat                          [d]             [d]                [d]
# season                     [u, a, w]          [u, a]             [u, a]
#
#                                   3               4                5   \
# family                Amanita Family  Amanita Family   Amanita Family
# name                     The Blusher       Death Cap  False Death Cap
# class                              e               p                e
# cap-diameter                    10.0             8.5              6.5
# cap-shape                     [x, f]          [x, f]              [x]
# Cap-surface                      NaN             [h]              NaN
# cap-color                        [n]             [r]           [w, y]
# does-bruise-or-bleed             [t]             [f]              [f]
# gill-attachment                  NaN             NaN              [e]
# gill-spacing                     NaN             [c]              NaN
# gill-color                       [w]             [w]              [w]
# stem-height                     11.0            11.0              6.0
# stem-width                      17.5            15.0             12.5
# stem-root                        [b]             NaN              [b]
# stem-surface                     NaN             NaN              NaN
# stem-color                       [w]             [w]           [w, y]
# veil-type                        [u]             [u]              [u]
# veil-color                       [w]             [w]           [y, w]
# has-ring                         [t]             [t]              [t]
# ring-type                        [g]          [g, p]              [g]
# Spore-print-color                NaN             NaN              NaN
# habitat                          [d]             [d]              [d]
# season                        [u, a]          [u, a]           [u, a]
#
#                                     6               7                 8   \
# family                  Amanita Family  Amanita Family    Lepiota Family
# name                  Destroying Angel  Tawny Grisette  Parasol Mushroom
# class                                p               e                 e
# cap-diameter                       7.5             6.0              17.5
# cap-shape                          [b]          [c, x]            [p, f]
# Cap-surface                        [t]          [h, t]               [y]
# cap-color                          [w]             [n]            [w, n]
# does-bruise-or-bleed               [f]             [f]               [f]
# gill-attachment                    [e]             [e]               NaN
# gill-spacing                       [c]             NaN               NaN
# gill-color                         [w]             [w]               [w]
# stem-height                       12.5            12.5              25.0
# stem-width                        12.5            12.5              20.0
# stem-root                          NaN             NaN               [s]
# stem-surface                       [y]             [s]               NaN
# stem-color                         [w]          [w, n]               [n]
# veil-type                          [u]             [u]               NaN
# veil-color                         [w]             [w]               NaN
# has-ring                           [t]             [f]               [t]
# ring-type                       [l, e]             [f]               [m]
# Spore-print-color                  NaN             NaN               NaN
# habitat                            [d]             [d]            [m, d]
# season                          [u, a]          [u, a]            [u, a]
#
#                                   9                 10                 11  \
# family                Lepiota Family    Lepiota Family  Tricholoma Family
# name                  Shaggy Parasol  Stinking Parasol    Saffron Parasol
# class                              e                 p                  p
# cap-diameter                    15.0               3.5                3.5
# cap-shape                        [x]            [b, f]                [x]
# Cap-surface                   [e, y]               [y]                [y]
# cap-color                        [n]      [e, n, p, w]             [y, n]
# does-bruise-or-bleed             [t]               [f]                [f]
# gill-attachment                  [e]               [e]                [a]
# gill-spacing                     NaN               [c]                NaN
# gill-color                       [w]            [n, w]                [w]
# stem-height                     10.0               4.5                5.5
# stem-width                      17.5               3.5                3.5
# stem-root                        NaN               NaN                NaN
# stem-surface                     NaN               [k]                [y]
# stem-color                       [w]               [w]             [y, n]
# veil-type                        NaN               NaN                NaN
# veil-color                       NaN               NaN                NaN
# has-ring                         [t]               [t]                [t]
# ring-type                        NaN               [e]                [r]
# Spore-print-color                NaN               NaN                NaN
# habitat                       [g, d]            [m, d]          [g, h, d]
# season                        [u, a]            [u, a]             [u, a]
#
#                                      12                 13                 14  \
# family                Tricholoma Family  Tricholoma Family  Tricholoma Family
# name                       The Deceiver  Amethyst Deceiver        Wood Blewit
# class                                 e                  e                  e
# cap-diameter                        2.5                2.5               10.0
# cap-shape                        [f, s]                [x]             [f, s]
# Cap-surface                         [y]                NaN                NaN
# cap-color                           [n]             [b, u]       [l, u, g, n]
# does-bruise-or-bleed                [f]                [f]                [f]
# gill-attachment                  [a, d]                NaN                [s]
# gill-spacing                        [d]                [d]                [c]
# gill-color                          [p]             [u, w]             [b, u]
# stem-height                         6.5                6.0                7.5
# stem-width                          3.5                4.5               20.0
# stem-root                           NaN                NaN                NaN
# stem-surface                        [i]                NaN                NaN
# stem-color                          [n]                [w]             [b, u]
# veil-type                           NaN                NaN                NaN
# veil-color                          NaN                NaN                NaN
# has-ring                            [f]                [f]                [f]
# ring-type                           [f]                [f]                [f]
# Spore-print-color                   NaN                NaN                NaN
# habitat                          [l, h]                [d]             [l, d]
# season                           [u, a]          [u, a, w]             [a, w]
#
#                                      15                 16  \
# family                Tricholoma Family  Tricholoma Family
# name                       Field Blewit     Clouded Agaric
# class                                 e                  e
# cap-diameter                        8.5               14.0
# cap-shape                     [x, f, s]          [x, f, s]
# Cap-surface                         NaN                [e]
# cap-color                        [g, n]             [g, n]
# does-bruise-or-bleed                [f]                [f]
# gill-attachment                     [s]             [a, d]
# gill-spacing                        [c]                [c]
# gill-color                       [g, p]                [w]
# stem-height                         7.0                8.5
# stem-width                         20.0               25.0
# stem-root                           [b]                [s]
# stem-surface                        NaN                NaN
# stem-color                          [u]                [w]
# veil-type                           NaN                NaN
# veil-color                          NaN                NaN
# has-ring                            [f]                [f]
# ring-type                           [f]                [f]
# Spore-print-color                   NaN                NaN
# habitat                          [g, d]             [l, d]
# season                           [a, w]             [a, w]
#
#                                           17                 18  \
# family                     Tricholoma Family  Tricholoma Family
# name                  Club-footed Funnel Cap  Common Funnel Cap
# class                                      p                  e
# cap-diameter                             6.0                6.0
# cap-shape                             [x, f]                [s]
# Cap-surface                              NaN                NaN
# cap-color                             [g, n]                [n]
# does-bruise-or-bleed                     [f]                [f]
# gill-attachment                          [d]                [d]
# gill-spacing                             [c]                [c]
# gill-color                            [w, y]                [w]
# stem-height                              5.5                5.0
# stem-width                              10.0                8.0
# stem-root                                [b]                NaN
# stem-surface                             NaN                [s]
# stem-color                               [n]                [w]
# veil-type                                NaN                NaN
# veil-color                               NaN                NaN
# has-ring                                 [f]                [f]
# ring-type                                [f]                [f]
# Spore-print-color                        NaN                NaN
# habitat                               [l, d]          [l, d, h]
# season                                [a, w]             [u, a]
#
#                                       19
# family                 Tricholoma Family
# name                  Aniseed Funnel Cap
# class                                  e
# cap-diameter                         4.5
# cap-shape                            [x]
# Cap-surface                          NaN
# cap-color                      [l, r, w]
# does-bruise-or-bleed                 [f]
# gill-attachment                   [a, d]
# gill-spacing                         NaN
# gill-color                           [r]
# stem-height                          6.0
# stem-width                           7.5
# stem-root                            NaN
# stem-surface                         NaN
# stem-color                     [l, r, w]
# veil-type                            NaN
# veil-color                           NaN
# has-ring                             [f]
# ring-type                            [f]
# Spore-print-color                    NaN
# habitat                           [l, d]
# season                            [u, a]

# %% [markdown]
# I decided to convert the intervals to numerical values in order to work better, so from having an interval with min and max I have only one value which is the mean.

# %%
mushrooms_train_df.columns
# Out:
# Index(['family', 'name', 'class', 'cap-diameter', 'cap-shape', 'Cap-surface',
#        'cap-color', 'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing',
#        'gill-color', 'stem-height', 'stem-width', 'stem-root', 'stem-surface',
#        'stem-color', 'veil-type', 'veil-color', 'has-ring', 'ring-type',
#        'Spore-print-color', 'habitat', 'season'],
#       dtype='object')

# %% [markdown]
# Cap-surface has an upper case--> i'll make it lower
#
#
# replace - with _

# %%
mushrooms_train_df.columns = mushrooms_train_df.columns.map(lambda x: x.lower().replace('-', '_'))

# %%
#check columns' names
mushrooms_train_df.columns
# Out:
# Index(['family', 'name', 'class', 'cap_diameter', 'cap_shape', 'cap_surface',
#        'cap_color', 'does_bruise_or_bleed', 'gill_attachment', 'gill_spacing',
#        'gill_color', 'stem_height', 'stem_width', 'stem_root', 'stem_surface',
#        'stem_color', 'veil_type', 'veil_color', 'has_ring', 'ring_type',
#        'spore_print_color', 'habitat', 'season'],
#       dtype='object')

# %% [markdown]
# In columns where I have only one value in the intervals, I transform the content by removing the square brackets and keeping only the value, to do this I deifnish and then apply the function:

# %%
def clean_range_values(x):
    # Check if the value is NaN, if so return it as is
    if pd.isna(x):
        return x

    # Check if the value contains square brackets
    match = re.match(r"\[([^\]]+)\]", str(x))
    if match:
        # If there is only one value inside the brackets, return it without brackets
        values = match.group(1).split(',')  # Split the value by commas if needed
        if len(values) == 1:  # Only remove brackets if there is a single value
            return values[0]

    # Return the value unchanged if no match or if there are multiple values inside the brackets
    return x

# %% [markdown]
# I do the copy of the original df and I try to apply the function on it too see the result

# %%
mushrooms_train_df1 = mushrooms_train_df.copy()
mushroom_train_df1_cleaned = mushrooms_train_df1.applymap(clean_range_values)
mushroom_train_df1_cleaned.head(20)
# Out:
# <ipython-input-82-1ee42a2fb65e>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   mushroom_train_df1_cleaned = mushrooms_train_df1.applymap(clean_range_values)
#                family                    name class  cap_diameter  cap_shape  \
# 0      Amanita Family              Fly Agaric     p          15.0     [x, f]
# 1      Amanita Family             Panther Cap     p           7.5     [p, x]
# 2      Amanita Family       False Panther Cap     p          12.5     [x, f]
# 3      Amanita Family             The Blusher     e          10.0     [x, f]
# 4      Amanita Family               Death Cap     p           8.5     [x, f]
# 5      Amanita Family         False Death Cap     e           6.5          x
# 6      Amanita Family        Destroying Angel     p           7.5          b
# 7      Amanita Family          Tawny Grisette     e           6.0     [c, x]
# 8      Lepiota Family        Parasol Mushroom     e          17.5     [p, f]
# 9      Lepiota Family          Shaggy Parasol     e          15.0          x
# 10     Lepiota Family        Stinking Parasol     p           3.5     [b, f]
# 11  Tricholoma Family         Saffron Parasol     p           3.5          x
# 12  Tricholoma Family            The Deceiver     e           2.5     [f, s]
# 13  Tricholoma Family       Amethyst Deceiver     e           2.5          x
# 14  Tricholoma Family             Wood Blewit     e          10.0     [f, s]
# 15  Tricholoma Family            Field Blewit     e           8.5  [x, f, s]
# 16  Tricholoma Family          Clouded Agaric     e          14.0  [x, f, s]
# 17  Tricholoma Family  Club-footed Funnel Cap     p           6.0     [x, f]
# 18  Tricholoma Family       Common Funnel Cap     e           6.0          s
# 19  Tricholoma Family      Aniseed Funnel Cap     e           4.5          x
#
#    cap_surface     cap_color does_bruise_or_bleed gill_attachment  \
# 0       [g, h]        [e, o]                    f               e
# 1            g             n                    f               e
# 2          NaN        [g, n]                    f               e
# 3          NaN             n                    t             NaN
# 4            h             r                    f             NaN
# 5          NaN        [w, y]                    f               e
# 6            t             w                    f               e
# 7       [h, t]             n                    f               e
# 8            y        [w, n]                    f             NaN
# 9       [e, y]             n                    t               e
# 10           y  [e, n, p, w]                    f               e
# 11           y        [y, n]                    f               a
# 12           y             n                    f          [a, d]
# 13         NaN        [b, u]                    f             NaN
# 14         NaN  [l, u, g, n]                    f               s
# 15         NaN        [g, n]                    f               s
# 16           e        [g, n]                    f          [a, d]
# 17         NaN        [g, n]                    f               d
# 18         NaN             n                    f               d
# 19         NaN     [l, r, w]                    f          [a, d]
#
#    gill_spacing gill_color  stem_height  stem_width stem_root stem_surface  \
# 0           NaN          w         17.5        17.5         s            y
# 1           NaN          w          8.0        15.0       NaN            y
# 2           NaN          w         11.0        15.0       NaN          NaN
# 3           NaN          w         11.0        17.5         b          NaN
# 4             c          w         11.0        15.0       NaN          NaN
# 5           NaN          w          6.0        12.5         b          NaN
# 6             c          w         12.5        12.5       NaN            y
# 7           NaN          w         12.5        12.5       NaN            s
# 8           NaN          w         25.0        20.0         s          NaN
# 9           NaN          w         10.0        17.5       NaN          NaN
# 10            c     [n, w]          4.5         3.5       NaN            k
# 11          NaN          w          5.5         3.5       NaN            y
# 12            d          p          6.5         3.5       NaN            i
# 13            d     [u, w]          6.0         4.5       NaN          NaN
# 14            c     [b, u]          7.5        20.0       NaN          NaN
# 15            c     [g, p]          7.0        20.0         b          NaN
# 16            c          w          8.5        25.0         s          NaN
# 17            c     [w, y]          5.5        10.0         b          NaN
# 18            c          w          5.0         8.0       NaN            s
# 19          NaN          r          6.0         7.5       NaN          NaN
#
#    stem_color veil_type veil_color has_ring ring_type spore_print_color  \
# 0           w         u          w        t    [g, p]               NaN
# 1           w         u          w        t         p               NaN
# 2           w         u          w        t    [e, g]               NaN
# 3           w         u          w        t         g               NaN
# 4           w         u          w        t    [g, p]               NaN
# 5      [w, y]         u     [y, w]        t         g               NaN
# 6           w         u          w        t    [l, e]               NaN
# 7      [w, n]         u          w        f         f               NaN
# 8           n       NaN        NaN        t         m               NaN
# 9           w       NaN        NaN        t       NaN               NaN
# 10          w       NaN        NaN        t         e               NaN
# 11     [y, n]       NaN        NaN        t         r               NaN
# 12          n       NaN        NaN        f         f               NaN
# 13          w       NaN        NaN        f         f               NaN
# 14     [b, u]       NaN        NaN        f         f               NaN
# 15          u       NaN        NaN        f         f               NaN
# 16          w       NaN        NaN        f         f               NaN
# 17          n       NaN        NaN        f         f               NaN
# 18          w       NaN        NaN        f         f               NaN
# 19  [l, r, w]       NaN        NaN        f         f               NaN
#
#       habitat     season
# 0           d  [u, a, w]
# 1           d     [u, a]
# 2           d     [u, a]
# 3           d     [u, a]
# 4           d     [u, a]
# 5           d     [u, a]
# 6           d     [u, a]
# 7           d     [u, a]
# 8      [m, d]     [u, a]
# 9      [g, d]     [u, a]
# 10     [m, d]     [u, a]
# 11  [g, h, d]     [u, a]
# 12     [l, h]     [u, a]
# 13          d  [u, a, w]
# 14     [l, d]     [a, w]
# 15     [g, d]     [a, w]
# 16     [l, d]     [a, w]
# 17     [l, d]     [a, w]
# 18  [l, d, h]     [u, a]
# 19     [l, d]     [u, a]

# %% [markdown]
# it worked--> CAN IT BE OKAY?????????? IN CASE WE CAN DO IT ON THE ORIGINAL DATASET

# %%
mushrooms_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   family                173 non-null    object
#  1   name                  173 non-null    object
#  2   class                 173 non-null    object
#  3   cap_diameter          173 non-null    float64
#  4   cap_shape             173 non-null    object
#  5   cap_surface           133 non-null    object
#  6   cap_color             173 non-null    object
#  7   does_bruise_or_bleed  173 non-null    object
#  8   gill_attachment       145 non-null    object
#  9   gill_spacing          102 non-null    object
#  10  gill_color            173 non-null    object
#  11  stem_height           173 non-null    float64
#  12  stem_width            173 non-null    float64
#  13  stem_root             27 non-null     object
#  14  stem_surface          65 non-null     object
#  15  stem_color            173 non-null    object
#  16  veil_type             9 non-null      object
#  17  veil_color            21 non-null     object
#  18  has_ring              173 non-null    object
#  19  ring_type             166 non-null    object
#  20  spore_print_color     18 non-null     object
#  21  habitat               173 non-null    object
#  22  season                173 non-null    object
# dtypes: float64(3), object(20)
# memory usage: 31.2+ KB

# %%
print(sum(mushrooms_train_df.isna().sum()))
print(mushrooms_train_df.duplicated().sum())
# Out:
# 871
# 0

# %% [markdown]
# there are no duplictaes

# %% [markdown]
# check null values:

# %%
mushrooms_train_df.isnull().sum()
# Out:
# family                    0
# name                      0
# class                     0
# cap_diameter              0
# cap_shape                 0
# cap_surface              40
# cap_color                 0
# does_bruise_or_bleed      0
# gill_attachment          28
# gill_spacing             71
# gill_color                0
# stem_height               0
# stem_width                0
# stem_root               146
# stem_surface            108
# stem_color                0
# veil_type               164
# veil_color              152
# has_ring                  0
# ring_type                 7
# spore_print_color       155
# habitat                   0
# season                    0
# dtype: int64

# %% [markdown]
# numeric variables don't have any null value

# %% [markdown]
# Based on these informations:<br>
# - there are a lot of Nan values in the columns **stem_root**, **stem_surface**,**veil_type**, **veil_color**, **spore_orint_color** --> WHAT CAN I DO? DROP? MAYBE THEY'RE USEFUL FOR NEXT ANALYSIS
# - **replace** the null values related the the others objects variables with their **mode** that is the value that occurs the  most in the variable, so it doesn't change the distirbution a lot

# %%
cap_surface_mode = mushrooms_train_df['cap_surface'].mode()[0]
mushrooms_train_df['cap_surface'] = mushrooms_train_df['cap_surface'].fillna(cap_surface_mode)
gill_attachment_mode = mushrooms_train_df['gill_attachment'].mode()[0]
mushrooms_train_df['gill_attachment'] = mushrooms_train_df['gill_attachment'].fillna(gill_attachment_mode)
gill_spacing_mode = mushrooms_train_df['cap_surface'].mode()[0]
mushrooms_train_df['gill_spacing'] = mushrooms_train_df['gill_spacing'].fillna(gill_spacing_mode)
ring_type_mode = mushrooms_train_df['ring_type'].mode()[0]
mushrooms_train_df['ring_type'] = mushrooms_train_df['ring_type'].fillna(ring_type_mode)

# %%
mushrooms_train_df.isnull().sum()
# Out:
# family                    0
# name                      0
# class                     0
# cap_diameter              0
# cap_shape                 0
# cap_surface               0
# cap_color                 0
# does_bruise_or_bleed      0
# gill_attachment           0
# gill_spacing              0
# gill_color                0
# stem_height               0
# stem_width                0
# stem_root               146
# stem_surface            108
# stem_color                0
# veil_type               164
# veil_color              152
# has_ring                  0
# ring_type                 0
# spore_print_color       155
# habitat                   0
# season                    0
# dtype: int64
